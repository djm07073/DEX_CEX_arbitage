# %%
import pandas as pd
import numpy as np
import requests
import json

# %%
baseAPIUrl = 'http://api.dexscreener.com/latest/dex/search?q=WBNB%20USDC'

# %%
data = requests.get(baseAPIUrl).json()

# %%
data
# Out:
# {'schemaVersion': '1.0.0',
#  'pairs': [{'chainId': 'bsc',
#    'dexId': 'pancakeswap',
#    'url': 'https://dexscreener.com/bsc/0xd99c7f6c65857ac913a8f880a4cb84032ab2fc5b',
#    'pairAddress': '0xd99c7F6C65857AC913a8f880A4cb84032AB2FC5b',
#    'labels': ['V2'],
#    'baseToken': {'address': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c',
#     'name': 'Wrapped BNB',
#     'symbol': 'WBNB'},
#    'quoteToken': {'address': '0x8AC76a51cc950d9822D68b83fE1Ad97B32Cd580d',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '246.9520',
#    'priceUsd': '246.95',
#    'txns': {'h24': {'buys': 1165, 'sells': 1289},
#     'h6': {'buys': 362, 'sells': 346},
#     'h1': {'buys': 45, 'sells': 58},
#     'm5': {'buys': 1, 'sells': 1}},
#    'volume': {'h24': 811930.38, 'h6': 244211.3, 'h1': 47170.51, 'm5': 2020.06},
#    'priceChange': {'h24': 0.68, 'h6': 0.99, 'h1': 0.01, 'm5': -0.18},
#    'liquidity': {'usd': 4456490.161731061, 'base': 9045.56, 'quote': 2228245},
#    'fdv': 910516821.46},
#   {'chainId': 'bsc',
#    'dexId': 'pancakeswap',
#    'url': 'https://dexscreener.com/bsc/0xd06d5c1fe526a5ded51672d03b621079fe70b21d',
#    'pairAddress': '0xd06d5c1Fe526A5Ded51672d03b621079Fe70b21d',
#    'labels': ['V2'],
#    'baseToken': {'address': '0x86886b6FCD34CA239EA9866D3955aB72241EA0e2',
#     'name': 'cUSDC',
#     'symbol': 'CUSDC'},
#    'quoteToken': {'address': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c',
#     'name': 'Wrapped BNB',
#     'symbol': 'WBNB'},
#    'priceNative': '0.000000000000000003749',
#    'priceUsd': '0.0000000000000009256',
#    'txns': {'h24': {'buys': 23, 'sells': 4},
#     'h6': {'buys': 23, 'sells': 4},
#     'h1': {'buys': 0, 'sells': 0},
#     'm5': {'buys': 0, 'sells': 0}},
#    'volume': {'h24': 169831.5, 'h6': 169831.5, 'h1': 0, 'm5': 0},
#    'priceChange': {'h24': -100, 'h6': -100, 'h1': 0, 'm5': 0},
#    'liquidity': {'usd': 2.403358866624662e-10,
#     'base': 100100100100100230000,
#     'quote': 0},
#    'pairCreatedAt': 1672493028000},
#   {'chainId': 'bsc',
#    'dexId': '0x1e895bFe59E3A5103e8B7dA3897d1F2391476f3c',
#    'url': 'https://dexscreener.com/bsc/0x5f5d385397095aaed4daffe336f9815ac598dff5',
#    'pairAddress': '0x5f5d385397095AaED4daffe336F9815AC598DFf5',
#    'baseToken': {'address': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c',
#     'name': 'Wrapped BNB',
#     'symbol': 'WBNB'},
#    'quoteToken': {'address': '0x8AC76a51cc950d9822D68b83fE1Ad97B32Cd580d',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '246.4397',
#    'priceUsd': '246.43',
#    'txns': {'h24': {'buys': 546, 'sells': 367},
#     'h6': {'buys': 182, 'sells': 104},
#     'h1': {'buys': 14, 'sells': 12},
#     'm5': {'buys': 1, 'sells': 1}},
#    'volume': {'h24': 46022.82, 'h6': 19986.13, 'h1': 1519.58, 'm5': 283.78},
#    'priceChange': {'h24': 0.11, 'h6': 2.29, 'h1': -2.03, 'm5': -2.12},
#    'liquidity': {'usd': 407295.93670868484, 'base': 819.23, 'quote': 203648},
#    'fdv': 908628030.34,
#    'pairCreatedAt': 1656990053000},
#   {'chainId': 'bsc',
#    'dexId': 'biswap',
#    'url': 'https://dexscreener.com/bsc/0x06cd679121ec37b0a2fd673d4976b09d81791856',
#    'pairAddress': '0x06Cd679121Ec37B0A2FD673D4976B09d81791856',
#    'baseToken': {'address': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c',
#     'name': 'Wrapped BNB',
#     'symbol': 'WBNB'},
#    'quoteToken': {'address': '0x8AC76a51cc950d9822D68b83fE1Ad97B32Cd580d',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '247.0645',
#    'priceUsd': '247.06',
#    'txns': {'h24': {'buys': 57, 'sells': 71},
#     'h6': {'buys': 18, 'sells': 22},
#     'h1': {'buys': 3, 'sells': 4},
#     'm5': {'buys': 0, 'sells': 0}},
#    'volume': {'h24': 21828.8, 'h6': 5917.11, 'h1': 2517.15, 'm5': 0},
#    'priceChange': {'h24': 1.2, 'h6': 0.84, 'h1': 0.17, 'm5': 0},
#    'liquidity': {'usd': 604480.1804007016, 'base': 1224.7, 'quote': 302240},
#    'fdv': 910931650.11},
#   {'chainId': 'bsc',
#    'dexId': 'babyswap',
#    'url': 'https://dexscreener.com/bsc/0xbf83ca11abc62447226f6b3566918d3594ba3803',
#    'pairAddress': '0xBF83cA11aBC62447226F6b3566918d3594bA3803',
#    'baseToken': {'address': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c',
#     'name': 'Wrapped BNB',
#     'symbol': 'WBNB'},
#    'quoteToken': {'address': '0x8AC76a51cc950d9822D68b83fE1Ad97B32Cd580d',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '246.3223',
#    'priceUsd': '246.32',
#    'txns': {'h24': {'buys': 39, 'sells': 38},
#     'h6': {'buys': 8, 'sells': 12},
#     'h1': {'buys': 0, 'sells': 2},
#     'm5': {'buys': 0, 'sells': 0}},
#    'volume': {'h24': 14751.47, 'h6': 4011.44, 'h1': 29.86, 'm5': 0},
#    'priceChange': {'h24': 0.56, 'h6': -0.15, 'h1': -0.3, 'm5': 0},
#    'liquidity': {'usd': 470632.34617493354, 'base': 953.48, 'quote': 235316},
#    'fdv': 908195216.1,
#    'pairCreatedAt': 1638694114000},
#   {'chainId': 'bsc',
#    'dexId': 'pancakeswap',
#    'url': 'https://dexscreener.com/bsc/0x4cd6e8dd2e837999c12744c66bf86d819d932458',
#    'pairAddress': '0x4cD6E8DD2E837999C12744C66bf86D819d932458',
#    'labels': ['V2'],
#    'baseToken': {'address': '0xF14D3692B0055Db9Ca4c04065165d59B87E763f1',
#     'name': 'MetaBUSDCoin',
#     'symbol': 'MBC'},
#    'quoteToken': {'address': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c',
#     'name': 'Wrapped BNB',
#     'symbol': 'WBNB'},
#    'priceNative': '0.000000000008956',
#    'priceUsd': '0.000000002212',
#    'txns': {'h24': {'buys': 2, 'sells': 9},
#     'h6': {'buys': 1, 'sells': 5},
#     'h1': {'buys': 0, 'sells': 0},
#     'm5': {'buys': 0, 'sells': 0}},
#    'volume': {'h24': 1802.1, 'h6': 1206.49, 'h1': 0, 'm5': 0},
#    'priceChange': {'h24': -2.57, 'h6': -1.81, 'h1': 0, 'm5': 0},
#    'liquidity': {'usd': 182987.7037978901,
#     'base': 41245966888406,
#     'quote': 370.34},
#    'fdv': 1075426.93,
#    'pairCreatedAt': 1639838510000},
#   {'chainId': 'bsc',
#    'dexId': 'sushiswap',
#    'url': 'https://dexscreener.com/bsc/0xc7632b7b2d768bbb30a404e13e1de48d1439ec21',
#    'pairAddress': '0xc7632B7b2d768bbb30a404E13E1dE48d1439ec21',
#    'baseToken': {'address': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c',
#     'name': 'Wrapped BNB',
#     'symbol': 'WBNB'},
#    'quoteToken': {'address': '0x8AC76a51cc950d9822D68b83fE1Ad97B32Cd580d',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '246.7084',
#    'priceUsd': '246.70',
#    'txns': {'h24': {'buys': 37, 'sells': 18},
#     'h6': {'buys': 11, 'sells': 5},
#     'h1': {'buys': 4, 'sells': 2},
#     'm5': {'buys': 1, 'sells': 0}},
#    'volume': {'h24': 1789.72, 'h6': 293.03, 'h1': 204.11, 'm5': 5},
#    'priceChange': {'h24': 1.03, 'h6': 0.18, 'h1': 0.04, 'm5': 0.03},
#    'liquidity': {'usd': 34883.20902115738, 'base': 70.89, 'quote': 17442},
#    'fdv': 909618645.42},
#   {'chainId': 'polygon',
#    'dexId': 'quickswap',
#    'url': 'https://dexscreener.com/polygon/0x56ea2342232ce09bc204e5f7d3641df4303bbd8a',
#    'pairAddress': '0x56Ea2342232ce09Bc204e5f7d3641Df4303BbD8a',
#    'labels': ['V2'],
#    'baseToken': {'address': '0xeCDCB5B88F8e3C15f95c720C51c71c9E2080525d',
#     'name': 'Wrapped BNB (Wormhole)',
#     'symbol': 'WBNB'},
#    'quoteToken': {'address': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174',
#     'name': 'USD Coin (PoS)',
#     'symbol': 'USDC'},
#    'priceNative': '246.6517',
#    'priceUsd': '246.65',
#    'txns': {'h24': {'buys': 51, 'sells': 40},
#     'h6': {'buys': 8, 'sells': 6},
#     'h1': {'buys': 0, 'sells': 1},
#     'm5': {'buys': 0, 'sells': 0}},
#    'volume': {'h24': 997.14, 'h6': 49.56, 'h1': 9.93, 'm5': 0},
#    'priceChange': {'h24': -2.18, 'h6': 0.28, 'h1': -0.86, 'm5': 0},
#    'liquidity': {'usd': 4165.19539, 'base': 8.46, 'quote': 2082.6},
#    'fdv': 919986.98,
#    'pairCreatedAt': 1637721418000},
#   {'chainId': 'bsc',
#    'dexId': 'jetswap',
#    'url': 'https://dexscreener.com/bsc/0x4b56ee85949164519bba2e454269de156930a4c8',
#    'pairAddress': '0x4b56EE85949164519bBa2e454269dE156930a4C8',
#    'baseToken': {'address': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c',
#     'name': 'Wrapped BNB',
#     'symbol': 'WBNB'},
#    'quoteToken': {'address': '0x8AC76a51cc950d9822D68b83fE1Ad97B32Cd580d',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '247.3742',
#    'priceUsd': '247.37',
#    'txns': {'h24': {'buys': 9, 'sells': 3},
#     'h6': {'buys': 5, 'sells': 2},
#     'h1': {'buys': 1, 'sells': 0},
#     'm5': {'buys': 0, 'sells': 0}},
#    'volume': {'h24': 70.15, 'h6': 40.92, 'h1': 4.31, 'm5': 0},
#    'priceChange': {'h24': 1.74, 'h6': 0.4, 'h1': 0.57, 'm5': 0},
#    'liquidity': {'usd': 4721.5791901915345, 'base': 9.55, 'quote': 2360.79},
#    'fdv': 912073563.6},
#   {'chainId': 'bsc',
#    'dexId': 'sphynx',
#    'url': 'https://dexscreener.com/bsc/0x10793a5a4b6981f61ee2eb488d37a6ecd893b8e3',
#    'pairAddress': '0x10793A5a4b6981F61eE2EB488d37a6eCD893B8e3',
#    'baseToken': {'address': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c',
#     'name': 'Wrapped BNB',
#     'symbol': 'WBNB'},
#    'quoteToken': {'address': '0x8AC76a51cc950d9822D68b83fE1Ad97B32Cd580d',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '247.8149',
#    'priceUsd': '247.81',
#    'txns': {'h24': {'buys': 4, 'sells': 1},
#     'h6': {'buys': 3, 'sells': 1},
#     'h1': {'buys': 0, 'sells': 0},
#     'm5': {'buys': 0, 'sells': 0}},
#    'volume': {'h24': 31.09, 'h6': 29.71, 'h1': 0, 'm5': 0},
#    'priceChange': {'h24': 0.88, 'h6': 0.88, 'h1': 0, 'm5': 0},
#    'liquidity': {'usd': 5392.679870326189, 'base': 10.88, 'quote': 2696.34},
#    'fdv': 913698544.56,
#    'pairCreatedAt': 1648568159000},
#   {'chainId': 'bsc',
#    'dexId': '0x542b6524aBF0Bd47Dc191504E38400Ec14D0290C',
#    'url': 'https://dexscreener.com/bsc/0xba906d5da0d32cb3219b4f7c67bcf047e111ea48',
#    'pairAddress': '0xbA906d5da0D32cb3219B4F7C67bcf047e111ea48',
#    'baseToken': {'address': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c',
#     'name': 'Wrapped BNB',
#     'symbol': 'WBNB'},
#    'quoteToken': {'address': '0x8AC76a51cc950d9822D68b83fE1Ad97B32Cd580d',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '246.4332',
#    'priceUsd': '246.43',
#    'txns': {'h24': {'buys': 1, 'sells': 0},
#     'h6': {'buys': 1, 'sells': 0},
#     'h1': {'buys': 1, 'sells': 0},
#     'm5': {'buys': 0, 'sells': 0}},
#    'volume': {'h24': 6.69, 'h6': 6.69, 'h1': 6.69, 'm5': 0},
#    'priceChange': {'h24': 0, 'h6': 0, 'h1': 0, 'm5': 0},
#    'liquidity': {'usd': 2670.7221489638396, 'base': 5.41, 'quote': 1335.36},
#    'fdv': 908604026.53,
#    'pairCreatedAt': 1638544345000},
#   {'chainId': 'bsc',
#    'dexId': 'pancakeswap',
#    'url': 'https://dexscreener.com/bsc/0x30479874f9320a62bce3bc0e315c920e1d73e278',
#    'pairAddress': '0x30479874f9320A62BcE3bc0e315C920E1D73E278',
#    'labels': ['V1'],
#    'baseToken': {'address': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c',
#     'name': 'Wrapped BNB',
#     'symbol': 'WBNB'},
#    'quoteToken': {'address': '0x8AC76a51cc950d9822D68b83fE1Ad97B32Cd580d',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '246.5612',
#    'priceUsd': '246.56',
#    'txns': {'h24': {'buys': 4, 'sells': 2},
#     'h6': {'buys': 1, 'sells': 0},
#     'h1': {'buys': 0, 'sells': 0},
#     'm5': {'buys': 0, 'sells': 0}},
#    'volume': {'h24': 5.57, 'h6': 0.49, 'h1': 0, 'm5': 0},
#    'priceChange': {'h24': 0.01, 'h6': 1.02, 'h1': 0, 'm5': 0},
#    'liquidity': {'usd': 156.19606501660604, 'base': 0.32, 'quote': 78.1},
#    'fdv': 909075996.7},
#   {'chainId': 'bsc',
#    'dexId': 'dinosaureggs',
#    'url': 'https://dexscreener.com/bsc/0x15c9f2368ba4e1031ab0cd1d4d0d0fc11033fc07',
#    'pairAddress': '0x15C9f2368bA4e1031Ab0Cd1D4D0d0fc11033fc07',
#    'baseToken': {'address': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c',
#     'name': 'Wrapped BNB',
#     'symbol': 'WBNB'},
#    'quoteToken': {'address': '0x8AC76a51cc950d9822D68b83fE1Ad97B32Cd580d',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '245.4330',
#    'priceUsd': '245.43',
#    'txns': {'h24': {'buys': 1, 'sells': 1},
#     'h6': {'buys': 0, 'sells': 0},
#     'h1': {'buys': 0, 'sells': 0},
#     'm5': {'buys': 0, 'sells': 0}},
#    'volume': {'h24': 5.01, 'h6': 0, 'h1': 0, 'm5': 0},
#    'priceChange': {'h24': 1.24, 'h6': 0, 'h1': 0, 'm5': 0},
#    'liquidity': {'usd': 2290.2806063898506, 'base': 4.66, 'quote': 1145.14},
#    'fdv': 904916369.27,
#    'pairCreatedAt': 1643885943000},
#   {'chainId': 'bsc',
#    'dexId': 'elkfinance',
#    'url': 'https://dexscreener.com/bsc/0xba6f62ad53e3883fabae0c10e2e0428e1328a96f',
#    'pairAddress': '0xbA6f62Ad53E3883fabAE0c10E2E0428e1328A96f',
#    'baseToken': {'address': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c',
#     'name': 'Wrapped BNB',
#     'symbol': 'WBNB'},
#    'quoteToken': {'address': '0x8AC76a51cc950d9822D68b83fE1Ad97B32Cd580d',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '247.0094',
#    'priceUsd': '247.00',
#    'txns': {'h24': {'buys': 2, 'sells': 0},
#     'h6': {'buys': 1, 'sells': 0},
#     'h1': {'buys': 0, 'sells': 0},
#     'm5': {'buys': 0, 'sells': 0}},
#    'volume': {'h24': 4.49, 'h6': 3.37, 'h1': 0, 'm5': 0},
#    'priceChange': {'h24': 0.8, 'h6': 0.8, 'h1': 0, 'm5': 0},
#    'liquidity': {'usd': 1118.2688041612614, 'base': 2.26, 'quote': 559.13},
#    'fdv': 910728669.71},
#   {'chainId': 'bsc',
#    'dexId': '0x97bCD9BB482144291D77ee53bFa99317A82066E8',
#    'url': 'https://dexscreener.com/bsc/0x1b449e513c9d55e1a5066e1c0753e60afceff361',
#    'pairAddress': '0x1b449e513C9D55E1a5066e1c0753e60afcEfF361',
#    'baseToken': {'address': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c',
#     'name': 'Wrapped BNB',
#     'symbol': 'WBNB'},
#    'quoteToken': {'address': '0x8AC76a51cc950d9822D68b83fE1Ad97B32Cd580d',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '243.6670',
#    'priceUsd': '243.66',
#    'txns': {'h24': {'buys': 1, 'sells': 1},
#     'h6': {'buys': 0, 'sells': 0},
#     'h1': {'buys': 0, 'sells': 0},
#     'm5': {'buys': 0, 'sells': 0}},
#    'volume': {'h24': 2.76, 'h6': 0, 'h1': 0, 'm5': 0},
#    'priceChange': {'h24': 0.49, 'h6': 0, 'h1': 0, 'm5': 0},
#    'liquidity': {'usd': 1182.5608510087807, 'base': 2.43, 'quote': 591.28},
#    'fdv': 898404970.9},
#   {'chainId': 'bsc',
#    'dexId': 'apeswap',
#    'url': 'https://dexscreener.com/bsc/0xd00302278693e5084e2b06a996d1d14ae3467fe6',
#    'pairAddress': '0xd00302278693E5084e2B06A996d1D14aE3467fE6',
#    'baseToken': {'address': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c',
#     'name': 'Wrapped BNB',
#     'symbol': 'WBNB'},
#    'quoteToken': {'address': '0x8AC76a51cc950d9822D68b83fE1Ad97B32Cd580d',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '245.4202',
#    'priceUsd': '245.42',
#    'txns': {'h24': {'buys': 4, 'sells': 11},
#     'h6': {'buys': 1, 'sells': 2},
#     'h1': {'buys': 1, 'sells': 2},
#     'm5': {'buys': 0, 'sells': 0}},
#    'volume': {'h24': 1.7, 'h6': 0.26, 'h1': 0.26, 'm5': 0},
#    'priceChange': {'h24': 0.74, 'h6': 0.63, 'h1': 0.63, 'm5': 0},
#    'liquidity': {'usd': 102.44596900541885, 'base': 0.21, 'quote': 51.22},
#    'fdv': 904869005.25},
#   {'chainId': 'bsc',
#    'dexId': 'bakeryswap',
#    'url': 'https://dexscreener.com/bsc/0xa439f6415a9dcab607844732a675f76dc5a0f9b9',
#    'pairAddress': '0xa439f6415A9DCAb607844732a675f76Dc5A0F9B9',
#    'baseToken': {'address': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c',
#     'name': 'Wrapped BNB',
#     'symbol': 'WBNB'},
#    'quoteToken': {'address': '0x8AC76a51cc950d9822D68b83fE1Ad97B32Cd580d',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '246.9597',
#    'priceUsd': '246.95',
#    'txns': {'h24': {'buys': 5, 'sells': 0},
#     'h6': {'buys': 2, 'sells': 0},
#     'h1': {'buys': 0, 'sells': 0},
#     'm5': {'buys': 0, 'sells': 0}},
#    'volume': {'h24': 1.4, 'h6': 1.08, 'h1': 0, 'm5': 0},
#    'priceChange': {'h24': 0.74, 'h6': 0.59, 'h1': 0, 'm5': 0},
#    'liquidity': {'usd': 602.978472430104, 'base': 1.22, 'quote': 301.49},
#    'fdv': 910545212.41},
#   {'chainId': 'bsc',
#    'dexId': '0xDf97982Bf70be91df4ACD3d511c551F06a0D19eC',
#    'url': 'https://dexscreener.com/bsc/0x3eadb5cb2cd2ac3887c81fa88bc46d4106cadf90',
#    'pairAddress': '0x3EaDb5cb2cD2AC3887c81fA88BC46D4106cADf90',
#    'baseToken': {'address': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c',
#     'name': 'Wrapped BNB',
#     'symbol': 'WBNB'},
#    'quoteToken': {'address': '0x8AC76a51cc950d9822D68b83fE1Ad97B32Cd580d',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '245.3930',
#    'priceUsd': '245.39',
#    'txns': {'h24': {'buys': 2, 'sells': 0},
#     'h6': {'buys': 0, 'sells': 0},
#     'h1': {'buys': 0, 'sells': 0},
#     'm5': {'buys': 0, 'sells': 0}},
#    'volume': {'h24': 1.01, 'h6': 0, 'h1': 0, 'm5': 0},
#    'priceChange': {'h24': 0.13, 'h6': 0, 'h1': 0, 'm5': 0},
#    'liquidity': {'usd': 1461.624992344945, 'base': 2.99, 'quote': 730.81},
#    'fdv': 904768927.95},
#   {'chainId': 'bsc',
#    'dexId': 'wault',
#    'url': 'https://dexscreener.com/bsc/0xa34337690711ce3f265f56ebd545dda00d7c0405',
#    'pairAddress': '0xA34337690711CE3F265f56Ebd545Dda00d7C0405',
#    'baseToken': {'address': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c',
#     'name': 'Wrapped BNB',
#     'symbol': 'WBNB'},
#    'quoteToken': {'address': '0x8AC76a51cc950d9822D68b83fE1Ad97B32Cd580d',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '245.3536',
#    'priceUsd': '245.35',
#    'txns': {'h24': {'buys': 0, 'sells': 1},
#     'h6': {'buys': 0, 'sells': 0},
#     'h1': {'buys': 0, 'sells': 0},
#     'm5': {'buys': 0, 'sells': 0}},
#    'volume': {'h24': 0.24, 'h6': 0, 'h1': 0, 'm5': 0},
#    'priceChange': {'h24': 0, 'h6': 0, 'h1': 0, 'm5': 0},
#    'liquidity': {'usd': 634.8718486525694, 'base': 1.29, 'quote': 317.44},
#    'fdv': 904623545.55},
#   {'chainId': 'bsc',
#    'dexId': '0x7810D4B7bC4F7faee9deec3242238a39c4f1197d',
#    'url': 'https://dexscreener.com/bsc/0x3f97fa8420d67d2b778c2b3318dd8c59fa0cc2ec',
#    'pairAddress': '0x3F97Fa8420d67D2b778C2b3318dd8c59fa0cC2Ec',
#    'baseToken': {'address': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c',
#     'name': 'Wrapped BNB',
#     'symbol': 'WBNB'},
#    'quoteToken': {'address': '0x8AC76a51cc950d9822D68b83fE1Ad97B32Cd580d',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '245.4238',
#    'priceUsd': '245.42',
#    'txns': {'h24': {'buys': 2, 'sells': 0},
#     'h6': {'buys': 0, 'sells': 0},
#     'h1': {'buys': 0, 'sells': 0},
#     'm5': {'buys': 0, 'sells': 0}},
#    'volume': {'h24': 0.2, 'h6': 0, 'h1': 0, 'm5': 0},
#    'priceChange': {'h24': 0.27, 'h6': 0, 'h1': 0, 'm5': 0},
#    'liquidity': {'usd': 146.07020626348015, 'base': 0.3, 'quote': 73.04},
#    'fdv': 904882525.27},
#   {'chainId': 'ethereum',
#    'dexId': 'uniswap',
#    'url': 'https://dexscreener.com/ethereum/0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#    'pairAddress': '0x88e6A0c2dDD26FEEb64F039a2c41296FcB3f5640',
#    'labels': ['v3'],
#    'baseToken': {'address': '0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2',
#     'name': 'Wrapped Ether',
#     'symbol': 'WETH'},
#    'quoteToken': {'address': '0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '1200.06050',
#    'priceUsd': '1200.060',
#    'txns': {'h24': {'buys': 2737, 'sells': 2900},
#     'h6': {'buys': 714, 'sells': 785},
#     'h1': {'buys': 170, 'sells': 149},
#     'm5': {'buys': 14, 'sells': 15}},
#    'volume': {'h24': 99732811.69,
#     'h6': 34247975.74,
#     'h1': 4735465.57,
#     'm5': 92767.42},
#    'priceChange': {'h24': 0.45, 'h6': 0.28, 'h1': 0.07, 'm5': -0.01},
#    'liquidity': {'usd': 180195755, 'base': 98762, 'quote': 61675756},
#    'fdv': 4613447397.42,
#    'pairCreatedAt': 1620250931000},
#   {'chainId': 'ethereum',
#    'dexId': 'uniswap',
#    'url': 'https://dexscreener.com/ethereum/0x3416cf6c708da44db2624d63ea0aaef7113527c6',
#    'pairAddress': '0x3416cF6C708Da44DB2624D63ea0AAef7113527C6',
#    'labels': ['v3'],
#    'baseToken': {'address': '0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'quoteToken': {'address': '0xdAC17F958D2ee523a2206206994597C13D831ec7',
#     'name': 'Tether USD',
#     'symbol': 'USDT'},
#    'priceNative': '1.0003000',
#    'priceUsd': '1.00',
#    'txns': {'h24': {'buys': 523, 'sells': 330},
#     'h6': {'buys': 110, 'sells': 85},
#     'h1': {'buys': 29, 'sells': 19},
#     'm5': {'buys': 6, 'sells': 0}},
#    'volume': {'h24': 37341576.1,
#     'h6': 9307756.1,
#     'h1': 6305920.62,
#     'm5': 95339.04},
#    'priceChange': {'h24': -0.01, 'h6': 0, 'h1': 0, 'm5': 0},
#    'liquidity': {'usd': 119595910, 'base': 42237305, 'quote': 77343790},
#    'fdv': 41453470168.1,
#    'pairCreatedAt': 1636825557000},
#   {'chainId': 'ethereum',
#    'dexId': 'uniswap',
#    'url': 'https://dexscreener.com/ethereum/0xe0554a476a092703abdb3ef35c80e0d76d32939f',
#    'pairAddress': '0xE0554a476A092703abdB3Ef35c80e0D76d32939F',
#    'labels': ['v3'],
#    'baseToken': {'address': '0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2',
#     'name': 'Wrapped Ether',
#     'symbol': 'WETH'},
#    'quoteToken': {'address': '0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '1200.3390',
#    'priceUsd': '1200.33',
#    'txns': {'h24': {'buys': 449, 'sells': 504},
#     'h6': {'buys': 111, 'sells': 147},
#     'h1': {'buys': 22, 'sells': 21},
#     'm5': {'buys': 0, 'sells': 2}},
#    'volume': {'h24': 29509504.78,
#     'h6': 5568618.02,
#     'h1': 280682.19,
#     'm5': 427.26},
#    'priceChange': {'h24': 0.5, 'h6': 0.26, 'h1': 0.12, 'm5': -0.01},
#    'liquidity': {'usd': 2756810, 'base': 1366, 'quote': 1116840},
#    'fdv': 4614517738.24,
#    'pairCreatedAt': 1636926269000},
#   {'chainId': 'arbitrum',
#    'dexId': 'uniswap',
#    'url': 'https://dexscreener.com/arbitrum/0xc31e54c7a869b9fcbecc14363cf510d1c41fa443',
#    'pairAddress': '0xC31E54c7a869B9FcBEcc14363CF510d1c41fa443',
#    'baseToken': {'address': '0x82aF49447D8a07e3bd95BD0d56f35241523fBab1',
#     'name': 'Wrapped Ether',
#     'symbol': 'WETH'},
#    'quoteToken': {'address': '0xFF970A61A04b1cA14834A43f5dE4533eBDDB5CC8',
#     'name': 'USD Coin (Arb1)',
#     'symbol': 'USDC'},
#    'priceNative': '1200.7028',
#    'priceUsd': '1200.70',
#    'txns': {'h24': {'buys': 3203, 'sells': 3905},
#     'h6': {'buys': 1009, 'sells': 1276},
#     'h1': {'buys': 120, 'sells': 59},
#     'm5': {'buys': 11, 'sells': 6}},
#    'volume': {'h24': 12491361.62,
#     'h6': 3735557.63,
#     'h1': 210012.31,
#     'm5': 29673.43},
#    'priceChange': {'h24': 0.56, 'h6': 0.26, 'h1': 0.07, 'm5': 0},
#    'liquidity': {'usd': 16401639, 'base': 8363.66, 'quote': 6359368},
#    'fdv': 274970740.71},
#   {'chainId': 'bsc',
#    'dexId': 'pancakeswap',
#    'url': 'https://dexscreener.com/bsc/0x16b9a82891338f9ba80e2d6970fdda79d1eb0dae',
#    'pairAddress': '0x16b9a82891338f9bA80E2D6970FddA79D1eb0daE',
#    'labels': ['V2'],
#    'baseToken': {'address': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c',
#     'name': 'Wrapped BNB',
#     'symbol': 'WBNB'},
#    'quoteToken': {'address': '0x55d398326f99059fF775485246999027B3197955',
#     'name': 'Tether USD',
#     'symbol': 'USDT'},
#    'priceNative': '246.3296',
#    'priceUsd': '246.32',
#    'txns': {'h24': {'buys': 24155, 'sells': 26608},
#     'h6': {'buys': 7223, 'sells': 7052},
#     'h1': {'buys': 799, 'sells': 632},
#     'm5': {'buys': 58, 'sells': 51}},
#    'volume': {'h24': 8222903.85,
#     'h6': 2138129.51,
#     'h1': 255409.76,
#     'm5': 19168.01},
#    'priceChange': {'h24': 0.39, 'h6': 0.64, 'h1': -0.51, 'm5': -0.52},
#    'liquidity': {'usd': 108875281.23392849, 'base': 220444, 'quote': 54437641},
#    'fdv': 908222111.17},
#   {'chainId': 'bsc',
#    'dexId': 'pancakeswap',
#    'url': 'https://dexscreener.com/bsc/0x5063cb58fe3bde9b6f1c2ad3a95a53e05d23beaa',
#    'pairAddress': '0x5063cb58fe3BdE9B6F1C2Ad3A95A53E05d23beaA',
#    'labels': ['V2'],
#    'baseToken': {'address': '0x35973F8Ada67c42Dfa199167641B197C6C6F9C7D',
#     'name': 'Pi NetWork',
#     'symbol': 'Pi'},
#    'quoteToken': {'address': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c',
#     'name': 'Wrapped BNB',
#     'symbol': 'WBNB'},
#    'priceNative': '0.0000000000146',
#    'priceUsd': '0.000000003608',
#    'txns': {'h24': {'buys': 5828, 'sells': 2810},
#     'h6': {'buys': 1229, 'sells': 585},
#     'h1': {'buys': 0, 'sells': 0},
#     'm5': {'buys': 0, 'sells': 0}},
#    'volume': {'h24': 8170100.44, 'h6': 1805459.78, 'h1': 0, 'm5': 0},
#    'priceChange': {'h24': -99.99, 'h6': -100, 'h1': 0, 'm5': 0},
#    'liquidity': {'usd': 49.08585950406646, 'base': 0, 'quote': 0.1},
#    'fdv': 72.7,
#    'pairCreatedAt': 1672332444000},
#   {'chainId': 'ethereum',
#    'dexId': 'uniswap',
#    'url': 'https://dexscreener.com/ethereum/0x5777d92f208679db4b9778590fa3cab3ac9e2168',
#    'pairAddress': '0x5777d92f208679DB4b9778590Fa3CAB3aC9e2168',
#    'labels': ['v3'],
#    'baseToken': {'address': '0x6B175474E89094C44Da98b954EedeAC495271d0F',
#     'name': 'Dai Stablecoin',
#     'symbol': 'DAI'},
#    'quoteToken': {'address': '0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '1.0000',
#    'priceUsd': '1.00',
#    'txns': {'h24': {'buys': 151, 'sells': 139},
#     'h6': {'buys': 60, 'sells': 34},
#     'h1': {'buys': 6, 'sells': 5},
#     'm5': {'buys': 1, 'sells': 0}},
#    'volume': {'h24': 6932768.31,
#     'h6': 4204283.83,
#     'h1': 463639.99,
#     'm5': 4060},
#    'priceChange': {'h24': 0, 'h6': 0, 'h1': -0.01, 'm5': 0},
#    'liquidity': {'usd': 235648181, 'base': 115184044, 'quote': 120463378},
#    'fdv': 5060816996.84,
#    'pairCreatedAt': 1636771503000},
#   {'chainId': 'bsc',
#    'dexId': 'pancakeswap',
#    'url': 'https://dexscreener.com/bsc/0xc70734ef92893cf7ae131b13874f8c531584fc4e',
#    'pairAddress': '0xC70734Ef92893CF7AE131b13874f8C531584fC4E',
#    'labels': ['V2'],
#    'baseToken': {'address': '0xB82BEb6Ee0063Abd5fC8E544c852237aA62CBb14',
#     'name': 'Square Token',
#     'symbol': 'SQUA'},
#    'quoteToken': {'address': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c',
#     'name': 'Wrapped BNB',
#     'symbol': 'WBNB'},
#    'priceNative': '0.08737',
#    'priceUsd': '21.55',
#    'txns': {'h24': {'buys': 2193, 'sells': 1963},
#     'h6': {'buys': 234, 'sells': 167},
#     'h1': {'buys': 32, 'sells': 25},
#     'm5': {'buys': 3, 'sells': 1}},
#    'volume': {'h24': 6024259.35,
#     'h6': 254577.53,
#     'h1': 54463.15,
#     'm5': 227.28},
#    'priceChange': {'h24': -26.4, 'h6': 0.52, 'h1': -0.35, 'm5': -0.51},
#    'liquidity': {'usd': 5085745.912698049, 'base': 117687, 'quote': 10309},
#    'fdv': 107767505,
#    'pairCreatedAt': 1641864317000},
#   {'chainId': 'bsc',
#    'dexId': 'pancakeswap',
#    'url': 'https://dexscreener.com/bsc/0x58f876857a02d6762e0101bb5c46a8c1ed44dc16',
#    'pairAddress': '0x58F876857a02D6762E0101bb5C46A8c1ED44Dc16',
#    'labels': ['V2'],
#    'baseToken': {'address': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c',
#     'name': 'Wrapped BNB',
#     'symbol': 'WBNB'},
#    'quoteToken': {'address': '0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56',
#     'name': 'BUSD Token',
#     'symbol': 'BUSD'},
#    'priceNative': '247.2846',
#    'priceUsd': '247.28',
#    'txns': {'h24': {'buys': 14244, 'sells': 11201},
#     'h6': {'buys': 4194, 'sells': 3455},
#     'h1': {'buys': 651, 'sells': 490},
#     'm5': {'buys': 63, 'sells': 55}},
#    'volume': {'h24': 5594298.07,
#     'h6': 1623966.05,
#     'h1': 222560.38,
#     'm5': 29843.21},
#    'priceChange': {'h24': 1.36, 'h6': 0.44, 'h1': 0.43, 'm5': -0.03},
#    'liquidity': {'usd': 153715005.85228133, 'base': 311585, 'quote': 76857503},
#    'fdv': 911743342.61},
#   {'chainId': 'ethereum',
#    'dexId': 'uniswap',
#    'url': 'https://dexscreener.com/ethereum/0x65a364c98aa6554932b551471e7873d9617047d4',
#    'pairAddress': '0x65A364c98AA6554932B551471E7873D9617047D4',
#    'labels': ['v2'],
#    'baseToken': {'address': '0xbc138bD20C98186CC0342C8e380953aF0cb48BA8',
#     'name': 'Candle',
#     'symbol': 'CNDL'},
#    'quoteToken': {'address': '0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '0.00001676',
#    'priceUsd': '0.00001676',
#    'txns': {'h24': {'buys': 2, 'sells': 1},
#     'h6': {'buys': 2, 'sells': 1},
#     'h1': {'buys': 0, 'sells': 0},
#     'm5': {'buys': 0, 'sells': 0}},
#    'volume': {'h24': 5305064.79, 'h6': 5305064.79, 'h1': 0, 'm5': 0},
#    'priceChange': {'h24': -100, 'h6': -100, 'h1': 0, 'm5': 0},
#    'liquidity': {'usd': 2652520, 'base': 0.1226, 'quote': 2652520},
#    'fdv': 1676247.84,
#    'pairCreatedAt': 1641628568000}]}

# %%
data_1 = data['pairs']

# %%
len(data_1)
# Out:
# 30

# %%
data_1[1]['chainId']
# Out:
# 'bsc'

# %%
chainId = []
dexId = []
url = []
pairAddress = []
baseToken_address = [] 
baseToken_name = []
baseToken_symbol = []
quoteToken_symbol = []
priceNative = []
priceUsd =[]
txns_m5_buys = []
txns_m5_sells = []
txns_h1_buys = []
txns_h1_sells = []
txns_h6_buys = []
txns_h6_sells = []
txns_h24_buys = []
txns_h24_sells = []
volume_m5 = []
volume_h1 = []
volume_h6 = []
volume_h24 = []
priceChange_m5 = []
priceChange_h1 = []
priceChange_h6 = []
priceChange_h24 = []
liquidity_usd = []
liquidity_base = []
liquidity_quote = []

for j in range(len(data_1)):
    for i in range(len(data_1[1])):
        chainId.append(data_1[i]["chainId"])
        dexId.append(data_1[i]["dexId"])
        url.append(data_1[i]["url"])
        pairAddress.append(data_1[i]["pairAddress"])
        baseToken_address.append(data_1[i]["baseToken"]["address"])
        baseToken_name.append(data_1[i]["baseToken"]["name"])
        baseToken_symbol.append(data_1[i]["baseToken"]["symbol"])
        quoteToken_symbol.append(data_1[i]["quoteToken"]["symbol"])
        priceNative.append(data_1[i]["priceNative"])
        priceUsd.append(data_1[i]["priceUsd"])
        txns_m5_buys.append(data_1[i]["txns"]["m5"]["buys"])
        txns_m5_sells.append(data_1[i]["txns"]["m5"]["sells"])
        txns_h1_buys.append(data_1[i]["txns"]["h1"]["buys"])
        txns_h1_sells.append(data_1[i]["txns"]["h1"]["sells"])
        txns_h6_buys.append(data_1[i]["txns"]["h6"]["buys"])
        txns_h6_sells.append(data_1[i]["txns"]["h6"]["sells"])
        txns_h24_buys.append(data_1[i]["txns"]["h24"]["buys"])
        txns_h24_sells.append(data_1[i]["txns"]["h24"]["sells"])
        volume_m5.append(data_1[i]["volume"]["m5"])
        volume_h1.append(data_1[i]["volume"]["h1"])
        volume_h6.append(data_1[i]["volume"]["h6"])
        volume_h24.append(data_1[i]["volume"]["h24"])
        priceChange_m5.append(data_1[i]["priceChange"]["m5"])
        priceChange_h1.append(data_1[i]["priceChange"]["h1"])
        priceChange_h6.append(data_1[i]["priceChange"]["h6"])
        priceChange_h24.append(data_1[i]["priceChange"]["h24"])
        liquidity_usd.append(data_1[i]["liquidity"]["usd"])
        liquidity_base.append(data_1[i]["liquidity"]["base"])
        liquidity_quote.append(data_1[i]["liquidity"]["quote"])

# %%
DEX_data = pd.Dataframe({"chainId":chainId,
                        "dexId":dexId,
                        "url":url,
                        "pairAddress":pairAddress,
                        "baseToken_address":baseToken_address,
                        "baseToken_name":baseToken_name,
                        "baseToken_symbol":baseToken_symbol,
                        "quoteToken_symbol":quoteToken_symbol,
                        "priceNative":priceNative,
                        "priceUsd":priceUsd,
                        "txns_m5_buys":txns_m5_buys,
                        "txns_m5_sells":txns_m5_sells,
                        "txns_h1_buys":txns_h1_buys,
                        "txns_h1_sells":txns_h1_sells,
                        "txns_h6_buys":txns_h6_buys,
                        "txns_h6_sells":txns_h6_sells,
                        "txns_h24_buys":txns_h24_buys,
                        "txns_h24_sells":txns_h24_sells,
                        "volume_m5":volume_m5,
                        "volume_h1":volume_h1,
                        "volume_h6":volume_h6,
                        "volume_h24":volume_h24,
                        "priceChange_m5":priceChange_m5,
                        "priceChange_h1":priceChange_h1,
                        "priceChange_h6":priceChange_h6,
                        "priceChange_h24":priceChange_h24,
                        "liquidity_usd":liquidity_usd,
                        "liquidity_base":liquidity_base,
                        "liquidity_quote":liquidity_quote
                        })
# Out:
#   File "<ipython-input-99-b652bad09703>", line 1
#     DEX_data = pd.Dataframe{"chainId":chainId,
#                            ^
# SyntaxError: invalid syntax
